# %%
import pandas as pd
import re
import numpy as np

# %%
players = pd.read_csv('players.csv')
countries = pd.read_csv('countries.csv')
events = pd.read_csv('events.csv')

# %%
# Count all players whos name's start with AEIOU
players['name'].str.extract('^([AEIOU].*)').count()
# Out:
# 84

# %%
# Find all players from the 'USA' whos name starts with an 'A'
players[players.country_id == 'USA'][players['name'].str.contains('(^[Aa].*)')]
# Out:
#                                         name   player_id country_id  \
# 1   Aaron Peirsol                             PEIRSAAR01        USA
# 3   Adam Nelson                               NELSOADA01        USA
# 15  Allyson Felix                             FELIXALL01        USA
# 16  Alvin Harrison                            HARRIALV01        USA
# 17  Amanda Beard                              BEARDAMA01        USA
# 18  Amanda Weir                               WEIRAMA01         USA
# 19  Amy van Dyken                             VANDYAMY01        USA
# 25  Angelo Taylor                             TAYLOANG02        USA
# 30  Anthony Ervin                             ERVINANT01        USA
# 32  Antonio Pettigrew                         PETTIANT01        USA
#
#      birthdate
# 1   1978-08-26
# 3   1984-10-13
# 15  1975-01-04
# 16  1976-05-15
# 17  1980-10-22
# 18  1979-01-09
# 19  1983-07-26
# 25  1974-08-24
# 30  1972-02-14
# 32  1976-03-21
#
# [10 rows x 4 columns]

# %%
# Construct a dataframe with two columns: country_name, num_players
join = pd.merge(players, countries, on='country_id')
players.groupby('country_id').size()
# Out:
# country_id
# ALG            4
# ARG            1
# AUS           34
# AUT            2
# BAH            5
# BAR            1
# BLR            7
# BRA            9
# BUL            1
# CAN            1
# CHN            8
# CMR            1
# CRC            1
# CRO            1
# CUB           12
# CZR            3
# DEN            2
# DOM            1
# ERI            1
# ESP            4
# EST            2
# ETH           12
# FIN            1
# FRA           10
# GBR           12
# GER           22
# GRE            7
# HUN            4
# IRL            1
# ISL            1
# ITA           12
# JAM           18
# JPN           16
# KAZ            2
# KEN           13
# KSA            1
# LAT            2
# LTU            2
# MAR            5
# MEX            3
# MOZ            1
# NED           13
# NGR           12
# NOR            3
# POL            5
# POR            3
# ROM           10
# RSA           10
# RUS           38
# SLO            1
# SRI            1
# SVK            1
# SWE            9
# TRI            2
# TUR            1
# UKR            9
# USA           88
# ZIM            1
# Length: 58, dtype: int64

# %%
# Convert the above left outer join query (last question in the SQL assignment) into pandas equivalent
# i.e. find the number of players in each country born in 1975
joined = pd.merge(players, countries, how='left', on='country_id')
only1975 = joined[joined.birthdate.str.contains('(^1975.*)')].groupby('country_id').size()
only1975 = pd.DataFrame(only1975)
#panel = pd.Panel({'country_id' : only1975['country_id']})
#only1975 = only1975.drop(['name_x', 'player_id', 'country_id', 'name_y', 'area_sqkm', 'population'], axis=1, level=None, inplace=False)
#c = pd.DataFrame(only1975.drop(['birthdate'], axis=1, level=None, inplace=False), columns=['country_id'])
only1975 = pd.concat([only1975, countries], axis=1).drop(['area_sqkm', 'population', 'country_id'], axis=1, level=None, inplace=False)
only1975 = only1975.drop([], axis=0, level=None, inplace=False).fillna(0)
only1975

# I tried so many things to merge the only1975 table with the countries table. I got it to work but I can't figure out
# how to sort it or rename columns or anything
# Out:
#      0                                      name
# 0    0  Algeria
# 1    0  Argentina
# 2    0  Australia
# 3    0  Austria
# 4    0  The Bahamas
# 5    0  Barbados
# 6    0  Belarus
# 7    0  Brazil
# 8    0  Bulgaria
# 9    0  Canada
# 10   0  China
# 11   0  Cameroon
# 12   0  Costa Rica
# 13   0  Croatia
# 14   0  Cuba
# 15   0  Czech Republic
# 16   0  Denmark
# 17   0  Dominican Republic
# 18   0  Eritrea
# 19   0  Spain
# 20   0  Estonia
# 21   0  Ethiopia
# 22   0  Finland
# 23   0  France
# 24   0  United Kingdom
# 25   0  Germany
# 26   0  Greece
# 27   0  Hungary
# 28   0  Ireland
# 29   0  Iceland
# 30   0  Italy
# 31   0  Jamaica
# 32   0  Japan
# 33   0  Kazakhstan
# 34   0  Kenya
# 35   0  Saudi Arabia
# 36   0  Latvia
# 37   0  Lithuania
# 38   0  Morocco
# 39   0  Mexico
# 40   0  Mozambique
# 41   0  Netherlands
# 42   0  Nigeria
# 43   0  Norway
# 44   0  Poland
# 45   0  Portugal
# 46   0  Romania
# 47   0  South Africa
# 48   0  Russia
# 49   0  Slovenia
# 50   0  Sri Lanka
# 51   0  Slovakia
# 52   0  Sweden
# 53   0  Trinidad and Tobago
# 54   0  Turkey
# 55   0  Ukraine
# 56   0  United States
# 57   0  Zimbabwe
# AUS  3                                         0
# BLR  1                                         0
#     ..                                       ...
#
# [78 rows x 2 columns]
